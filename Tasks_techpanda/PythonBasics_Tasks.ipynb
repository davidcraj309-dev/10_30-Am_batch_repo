# %% [markdown]
# ### **Python Basics & Control Statements Tasks:**
# ******

# %% [markdown]
# ##### **1. Python Basics**
#
# ##### *1.Write a Python program to store your name, age, city, and profession in variables and display them.*

# %%
name  = "david"
age = 27
city = "chennai"
profession = "Generative Ai Engineer"

print(f"i'm {name} and my age is {age} years old,\n"
    f"currently pursuing a{profession} course at TechPanda Academy.")
# Out:
# i’m david and my age is 27 years old,
# currently pursuing aGenerative Ai Engineer course at TechPanda Academy.

# %% [markdown]
# ##### *2.Write a program to input two numbers and display their sum, difference, product, and quotient.*

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1+num2
print("Sum: ",sum)

difference = num1-num2
print("difference:",difference)

product = num1*num2
print("product:",product)

quotient = num1//num2
print("quotient:",quotient)
# Out:
# Sum:  15
# difference: -1
# product: 56
# quotient: 0

# %% [markdown]
# ##### *2.Write a program to input the length and breadth of a rectangle and calculate its area and perimeter.*

# %%
length  = int(input("Enter a Length:"))
breadth  = int(input("Enter a breadth"))

area = length * breadth
print("area:",area)

perimeter = length+breadth+length+breadth
print("perimeter:",perimeter)
# Out:
# area: 100
# perimeter: 40

# %% [markdown]
# ##### *4.Write a program to convert temperature from Celsius to Fahrenheit.*

# %%
Celsius = float(input("Enter Celsius: "))

Fahrenheit = (Celsius*1.8+32)   
print(f"Fahrenheit: {Fahrenheit}°F")
# Out:
# Fahrenheit: 132.8°F

# %% [markdown]
# ##### *5.Write a program to input a student's name and marks in three subjects and display the total and average.*

# %%
student_name = (input("Enter student name:"))

subject_1 = int(input("Enter marks for Subject 1: "))
subject_2 = int(input("Enter marks for Subject 2: "))
subject_3 = int(input("Enter marks for Subject 3: "))


total = subject_1 + subject_2 + subject_3
average = total/3
print("name: ",student_name)
print("total:",total)
print("average:",average)
# Out:
# name:  david
# total: 189
# average: 63.0

# %% [markdown]
# ##### *6.Write a program to swap the values of two variables.*

# %%
a = 10
b = 20

a,b = b,a
print("a:",a)
print("b:",b)
# Out:
# a: 20
# b: 10

# %% [markdown]
# ##### *7.Write a program to input a number and display its square and cube.*

# %%
num  = int(input("Enter a Number:"))


square = num**2
print("square",square)

cube = num**3
print("cube",cube)
# Out:
# square 36
# cube 216

# %% [markdown]
# ##### *7.Write a program to calculate simple interest using principal, rate, and time.*

# %%
principal = int(input("Enter a principal: "))
rate = int(input("Enter a rate: "))
time = int(input("Enter a time: "))

simple_interest = (principal*rate*time)/100

print("simple_interest: ",simple_interest)
# Out:
# simple_interest:  112000.0

# %% [markdown]
# *********************

# %% [markdown]
# ##### **2. Operators**
#
# ##### *9.Write a program to demonstrate all arithmetic operators using two numbers.*
#
# A mathamatical functions operation called operators
#
# Arithmetic operters - +Addition , -substractions , *multification , /Division, **powerof, //Quotient , %Remainder

# %%
num1  = int(input("Enter a Number1:"))
num2  = int(input("Enter a Number2:"))

addition = num1  + num2
print("addition:",addition)

subtraction = num1  -  num2
print("subtraction",subtraction)

multification = num1  *  num2
print("multification",multification)

Division = num1 / num2
print("Division:",Division)

powerof = num1**num2
print("powerof:",powerof)

Quotient = num1 // num2
print("Quotient:",Quotient)

Remainder = num1 % num2
print("Remainder",Remainder)
# Out:
# addition: 11
# subtraction -1
# multification 30
# Division: 0.8333333333333334
# powerof: 15625
# Quotient: 0
# Remainder 5

# %% [markdown]
# ##### *10.Write a program to demonstrate comparison operators using two numbers.*
#
# | Comparison operators | `==`, `!=`, `>`, `<`, `<=`, `>=`                |

# %%
num1  = int(input("Enter a Number1:"))
num2  = int(input("Enter a Number2:"))

Equal_to = num1 == num2
print("Equal_to:",Equal_to)

Not_equal_to = num1 != num2
print("Not_equal_to:",Not_equal_to)

Greater_than = num1>num2
print("Greater_than:",Greater_than)

Less_than = num1<num2
print("Less_than:",Less_than)

Greater_than_or_equal = num1>=num2
print("Greater_than_or_equal:",Greater_than_or_equal)

Less_than_or_equal = num1<=num2
print("Less_than_or_equal:",Less_than_or_equal)
# Out:
# Equal_to: False
# Not_equal_to: True
# Greater_than: False
# Less_than: True
# Greater_than_or_equal: False
# Less_than_or_equal: True

# %% [markdown]
# ##### *11.Write a program to demonstrate assignment operators (=, +=, -=, *=, /=, //=, %=, **=).*

# %%
num = 10
print("Assignment:",num)

num  += 2
print("Add and assign:",num)

num -= 2
print("Subtract and assign:",num)

num *= 2
print("Multiply and assign:",num)

num /= 2
print("Divide and assign:",num)

num //= 2
print("Quotient and assign:",num)

num %= 2
print("Modulus and assign:",num)

num **= 2
print("Exponentiate and assign:",num)
# Out:
# Assignment: 10
# Add and assign: 12
# Subtract and assign: 10
# Multiply and assign: 20
# Divide and assign: 10.0
# Quotient and assign: 5.0
# Modulus and assign: 1.0
# Exponentiate and assign: 1.0

# %% [markdown]
# ##### *12.Write a program to check whether a number is divisible by both 3 and 5 using logical operators.*

# %%
num = int(input("Enter a Number:  "))

if num%3==0 and num%5==0:
    print(num,"number is divisible by 3 & 5")
else:
    print(num,"number is Not divisible by 3 & 5")
# Out:
# 15 number is divisable by 3 & 5

# %% [markdown]
# ##### *13.Write a program to check whether a number is positive and even using logical operators.*

# %%
num = int(input("Enter a Number:  "))

if num>0 and num%2==0:
    print(num,"number is positive & even")
else:
    print(num,"number is Not positive & even")
# Out:
# -1 number is Not positive & even

# %% [markdown]
# ##### *14.Write a program to demonstrate the difference between /, //, and % operators.*

# %% [markdown]
#  * /Division → gives the exact result
#  * //Quotient → gives the whole-number quotient
#  * %Remainder → gives the remainder

# %%
num1  = int(input("Enter a Number1:"))
num2  = int(input("Enter a Number2:"))


Division = num1 / num2
print("Division:",Division)

Quotient = num1 // num2
print("Quotient:",Quotient)

Remainder = num1 % num2
print("Remainder",Remainder)
# Out:
# Division: 0.7142857142857143
# Quotient: 0
# Remainder 5

# %% [markdown]
# ##### *15.Write a program to calculate the result of an expression containing +, -, *, /, //, %, and** *

# %%
num1  = int(input("Enter a Number1:"))
num2  = int(input("Enter a Number2:"))

result = num1 + num2 -num1 * num2 / num1 ** num2 // num1 % num2

print("result:",result)
# Out:
# result: 15.0

# %% [markdown]
# ##### *16.Write a program to check whether a given character is present in a string using membership operators.*

# %%
name = input("Enter a string: ")
char = input("Enter a character: ")

if char in name:
    print("yes")
else:
    print("No")
# Out:
# yes

# %% [markdown]
# ****************************

# %% [markdown]
# ##### **3. if, elif and else**
#
# ##### *17.Write a program to check whether a number is positive, negative, or zero.*

# %%
num = int(input("Enter a Number: "))

if num>0:
    print("the number is postive")
elif num<0:
    print("the number is negative")
elif num==0:
    print("the number is Zero")
else:
    print("Enter a vaild number")
# Out:
# the number is Zero

# %% [markdown]
# ##### *18.Write a program to check whether a number is even or odd.*

# %%
num = int(input("Enter a Number: "))

if num%2==0:
    print("the number even")
else:
    print("the number odd")
# Out:
# the number odd

# %% [markdown]
# ##### *19.Write a program to find the largest of two numbers.*

# %%
num1 = int(input("Enter a num1: "))
num2 = int(input("Enter a num2: "))


if num1>num2:
    print("num1 is greater")
elif num2>num1:
    print("num2 is greater")
elif num1 == num2:
    print("Both are equal")
# Out:
# Both are equal

# %% [markdown]
# ##### *20.Write a program to find the largest of three numbers.*

# %%
num1 = int(input("Enter a num1: "))
num2 = int(input("Enter a num2: "))
num3 = int(input("Enter a num3: "))


if num1>num2 and num1>num3:
    print("num1 is greater ")

elif num2>num1 and num2>num3:
    print("num2 is greater")

elif num3>num1 and num3>num2:
    print("num3 is greater")

elif num1 == num2 == num3:
    print("All are equal")
# Out:
# All are equal

# %% [markdown]
# ##### *21.Write a program to check whether a person is eligible to vote based on age.*

# %%
age = int(input("Enter your age: "))

if age>=18:
    print("You are eligible to vote")
else:
    print("not eligible")
# Out:
# Your eligible to vote

# %% [markdown]
# ##### *22.Write a program to calculate grade based on marks: A for 90+, B for 75–89, C for 60–74, D for 40–59, and F below 40.*

# %%
marks = int(input("Enter your mark: "))

if marks>=90:
    print("Grade A")
elif marks>=75 and marks<=89:
    print("grade B")
elif marks>=60 and marks<=74:
    print("grade c")
elif marks>=40 and marks<=59:
    print("grade d")
elif marks<40:
    print("fail")
# Out:
# Grade A

# %% [markdown]
# ##### *23.Write a program to check whether a year is a leap year.*

# %%
year = int(input("Enter A year: "))

if year%400==0:
    print("Leap year")
elif year%4==0 and year%100!=0:
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Leap year

# %% [markdown]
# ##### *24.Write a program to create a simple calculator using if-elif-else.*

# %%
num1 = int(input("Enter a num1: "))
num2 = int(input("Enter a num2: "))
operator = input("Enter operator: ")

addition = num1+num2
subtraction = num1-num2
multification = num1*num2
Division = num1/num2
quotient = num1//num2
power_of = num1**num2


if operator == "+":
    print("addition", addition)

elif operator == "-":
    print("subtraction",subtraction)
    
elif operator == "*":
    print("multification",multification)

elif operator == "/":
    print("Division",Division)
    
elif operator == "//":
    print("quotient",quotient)

elif operator == "**":
    print("power_of",power_of)
# Out:
# multification 49

# %% [markdown]
# ##### *25.Write a program to check whether a given number is divisible by 5, divisible by 10, or neither.*

# %%
num = int(input("Enter a num: "))

if num%10==0:
    print("The number divisible by 10")
elif num%5==0:
    print("The number divisible by 5")
else:
    print("No divisible by 5 and 10")
# Out:
# The number divisible by 5

# %% [markdown]
# ##### *26.Write a program using while loop to print numbers from 1 to 10.*

# %%
num = 1

while num<=10:
    print("number:",num)
    num += 1
    
print("\nLoop is over")
# Out:
# number: 1
# number: 2
# number: 3
# number: 4
# number: 5
# number: 6
# number: 7
# number: 8
# number: 9
# number: 10
#
# Loop is over

# %% [markdown]
# ##### *27.Write a program using while loop to print numbers from 10 to 1.*

# %%
num = 10

while num>=1:
    print("number:",num)
    num -= 1
    
print("\nLoop is over")
# Out:
# number: 10
# number: 9
# number: 8
# number: 7
# number: 6
# number: 5
# number: 4
# number: 3
# number: 2
# number: 1
#
# Loop is over

# %% [markdown]
# ##### *28.Write a program using while loop to print all even numbers from 1 to 50.*

# %%
num = 1

while num<=50:
    if num%2==0:
        print("Even Number: ",num)
    num += 1

print("\nLoop over")
# Out:
# Even Number:  2
# Even Number:  4
# Even Number:  6
# Even Number:  8
# Even Number:  10
# Even Number:  12
# Even Number:  14
# Even Number:  16
# Even Number:  18
# Even Number:  20
# Even Number:  22
# Even Number:  24
# Even Number:  26
# Even Number:  28
# Even Number:  30
# Even Number:  32
# Even Number:  34
# Even Number:  36
# Even Number:  38
# Even Number:  40
# Even Number:  42
# Even Number:  44
# Even Number:  46
# Even Number:  48
# Even Number:  50
#
# Loop over

# %% [markdown]
# ##### *29.Write a program using while loop to print all odd numbers from 1 to 50.*

# %%
num = 1

while num<=50:
    if num%2!=0:
        print("Odd number:",num)
    num += 1

print("\n loop over")
# Out:
# Odd number: 1
# Odd number: 3
# Odd number: 5
# Odd number: 7
# Odd number: 9
# Odd number: 11
# Odd number: 13
# Odd number: 15
# Odd number: 17
# Odd number: 19
# Odd number: 21
# Odd number: 23
# Odd number: 25
# Odd number: 27
# Odd number: 29
# Odd number: 31
# Odd number: 33
# Odd number: 35
# Odd number: 37
# Odd number: 39
# Odd number: 41
# Odd number: 43
# Odd number: 45
# Odd number: 47
# Odd number: 49
#
#  loop over

# %% [markdown]
# ##### *29.Write a program using while loop to print all odd numbers from 1 to 50.*
